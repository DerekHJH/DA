# %% [markdown]
# # DAViT

# %% [markdown]
# ## Import Libraries

# %%
import os
import sys
import datetime
import random
import numpy as np
import pandas as pd

import torch 
from torch import nn
from torch.utils.data import Dataset,DataLoader
from torchvision import transforms,datasets 
from torch import einsum

from einops import rearrange, repeat
from einops.layers.torch import Rearrange

from matplotlib import pyplot as plt 

from torchsummary import summary

# %% [markdown]
# ## Utilities

# %%
def printbar():
    nowtime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("\n"+"=========="*8 + "%s"%nowtime)

# %% [markdown]
# ## Define Super-parameters

# %%
seed = 42
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# about the data set
train_path = '/global/cfs/cdirs/m3691/data/office/amazon/images'
valid_path = '/global/cfs/cdirs/m3691/data/office/dslr/images'
task_name = train_path.split('/')[-2] + '->' + valid_path.split('/')[-2]
channels = 3
image_size = 224
num_classes = 31

# about the data loader
batch_size = 32
num_workers = 16

# about the model
patch_size = 32
patch_side = image_size // patch_size
num_patches = patch_side * patch_side
dim = 1024
depth = 6
heads = 16
mlp_dim = 2048
emb_dropout = 0.1
dropout = 0.1

# about the optimizer
lr = 3e-5
gamma = 0.7

# about the training 
epochs = 750
log_step_freq = 1

# about saving and loading 
model_save_path = "./models/" + task_name
epochs_to_save = 1

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(seed)

# %% [markdown]
# ## Load Data

# %%
train_transforms = transforms.Compose(
    [
        transforms.Resize(image_size),
#         transforms.RandomResizedCrop(image_size),
#         transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
#         transforms.Normalize(mean=(0.1307, 0.1307, 0.1307), std=(0.3081, 0.3081, 0.3081)),
    ]
)

valid_transforms = transforms.Compose(
    [
        transforms.Resize(image_size),
#         transforms.RandomResizedCrop(image_size),
#         transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
#         transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)

# %%
train_data = datasets.ImageFolder(root = train_path, transform = train_transforms)
valid_data = datasets.ImageFolder(root = valid_path, transform = valid_transforms)

print(train_data.class_to_idx)
print()
print(len(train_data))
print(type(train_data[0]))
print(train_data[0][0].shape, train_data[0][1])
# Out:
# {'back_pack': 0, 'bike': 1, 'bike_helmet': 2, 'bookcase': 3, 'bottle': 4, 'calculator': 5, 'desk_chair': 6, 'desk_lamp': 7, 'desktop_computer': 8, 'file_cabinet': 9, 'headphones': 10, 'keyboard': 11, 'laptop_computer': 12, 'letter_tray': 13, 'mobile_phone': 14, 'monitor': 15, 'mouse': 16, 'mug': 17, 'paper_notebook': 18, 'pen': 19, 'phone': 20, 'printer': 21, 'projector': 22, 'punchers': 23, 'ring_binder': 24, 'ruler': 25, 'scissors': 26, 'speaker': 27, 'stapler': 28, 'tape_dispenser': 29, 'trash_can': 30}
#
# 2817
# <class 'tuple'>
# torch.Size([3, 224, 224]) 0

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, shuffle = True, num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size = batch_size, shuffle = True, num_workers = num_workers)

data, label = next(iter(train_loader))
print(data[0].shape, label[0])
# Out:
# torch.Size([3, 224, 224]) tensor(27)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# plt.figure(figsize=(8,8)) 
# for i in range(9):
#     img,label = train_data[i]
#     img = img.permute(1,2,0)
#     ax=plt.subplot(3,3,i+1)
#     ax.imshow(img.numpy())
#     ax.set_title("label = %d"%label)
#     ax.set_xticks([])
#     ax.set_yticks([]) 
# plt.show()

# %% [markdown]
# ## Define Model

# %%
class ReverseLayerF(torch.autograd.Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None

def pair(t):
    return t if isinstance(t, tuple) else (t, t)

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64, dropout = 0.):
        super().__init__()
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim = -1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = h), qkv)

        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        attn = self.attend(dots)

        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout = 0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads = heads, dim_head = dim_head, dropout = dropout)),
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout = dropout))
            ]))
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x

class ViT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool = 'cls', channels = 3, dim_head = 64, dropout = 0., emb_dropout = 0.):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'Image dimensions must be divisible by the patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        patch_dim = channels * patch_height * patch_width
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_height, p2 = patch_width),
            nn.Linear(patch_dim, dim),
        )

        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.dropout = nn.Dropout(emb_dropout)
        self.pool = pool

        self.feature = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)
        self.class_classifier = nn.Sequential()
#         self.class_classifier.add_module('c_ln', nn.LayerNorm(dim))
        self.class_classifier.add_module('c_fc1', nn.Linear(dim, 100))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout())
        self.class_classifier.add_module('c_fc2', nn.Linear(100, 100))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(100))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(100, num_classes))

        self.domain_classifier = nn.Sequential()
#         self.domain_classifier.add_module('d_ln', nn.LayerNorm(dim))
        self.domain_classifier.add_module('d_fc1', nn.Linear(dim, 100))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(100))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(100, 2))


    def forward(self, img, alpha):
        x = self.to_patch_embedding(img)
        b, n, _ = x.shape

        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b = b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)

        feature = self.feature(x)
        feature = feature[:, 0]
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

# %%
model = ViT(
        image_size = image_size,
        patch_size = patch_size,
        num_classes = num_classes,
        dim = dim,
        depth = depth,
        heads = heads, 
        mlp_dim = mlp_dim,
        dropout = dropout,
        emb_dropout = emb_dropout
        ).to(device)
# summary(model, input_size = [[channels, image_size, image_size], [1]], batch_size = batch_size)

# %%
model.optimizer = torch.optim.Adam(model.parameters(), lr=lr)
model.criterion = nn.CrossEntropyLoss()
model.metric_func = lambda y_pred, y_true: (y_pred.argmax(dim = 1) == y_true).float().mean()
model.metric_name = "accuracy"

# %% [markdown]
# ## Train Model

# %%
def test(model, data_loader):
    #dropout layer stops working
    model.eval()
    
    len_loader = len(data_loader)
    data_iter = iter(data_loader)

    n_total = 0
    n_correct = 0

    for i in range(len_loader):
        img, label = data_iter.next()

        batch_size = len(label)

        img = img.to(device)
        label = label.to(device)

        class_output, _ = model(img = img, alpha = 0)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(label.data.view_as(pred)).cpu().sum()
        n_total += batch_size

    accu = n_correct.data.numpy() * 1.0 / n_total

    return accu

# %%
def train_model(model, epochs, train_loader, valid_loader, log_step_freq, model_save_path, epochs_to_save):
    
    dfhistory = pd.DataFrame(columns = ["epoch", "err_s_label", "err_s_domain", "err_t_domain", "err", "accu_s", "accu_t", "best_accu_s", "best_accu_t"])
    print("Start Training...")
#     nowtime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
#     print("=========="*8 + "%s"%nowtime)
    start_epoch = 1
    
    # load everything if existed
    if os.path.exists(model_save_path):
        checkpoint = torch.load(model_save_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        dfhistory = checkpoint['dfhistory']
        start_epoch = int(dfhistory.loc[dfhistory.shape[0] - 1]['epoch']) + 1
        
    best_accu_t = 0.0
    best_accu_s = 0.0
    for epoch in range(start_epoch, epochs + 1): 
        len_loader = min(len(train_loader), len(valid_loader))
        data_source_iter = iter(train_loader)
        data_target_iter = iter(valid_loader)
        # 1，training loop-------------------------------------------------
        step = 0
        err_s_label = 0
        err_s_domain = 0
        err_t_domain = 0
        err = 0
        for step in range(len_loader):
            model.train()
            p = float(step + epoch * len_loader) / epochs / len_loader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1
            
            # training model using source data
            s_img, s_label = data_source_iter.next()

            model.zero_grad()
            batch_size = len(s_label)
            domain_label = torch.zeros(batch_size).long()

            s_img = s_img.to(device)
            s_label = s_label.to(device)
            domain_label = domain_label.to(device)

            class_output, domain_output = model(img = s_img, alpha = alpha)
            err_s_label = model.criterion(class_output, s_label)
            err_s_domain = model.criterion(domain_output, domain_label)

            # training model using target data
            t_img, _ = data_target_iter.next()

            batch_size = len(t_img)

            domain_label = torch.ones(batch_size).long()

            t_img = t_img.to(device)
            domain_label = domain_label.to(device)

            _, domain_output = model(img = t_img, alpha = alpha)
            err_t_domain = model.criterion(domain_output, domain_label)
            err = err_t_domain + err_s_domain + err_s_label
            err.backward()
            model.optimizer.step()
            sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
              % (epoch, step + 1, len_loader, err_s_label.data.cpu().numpy(),
                 err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
            sys.stdout.flush()
            
        # 2，test-------------------------------------------------
        accu_s = test(model, train_loader)
        print('\nAccuracy of the source dataset: %f' % accu_s)
        accu_t = test(model, valid_loader)
        print('Accuracy of the target dataset: %f\n' % accu_t)
        if accu_t > best_accu_t:
            best_accu_s = accu_s
            best_accu_t = accu_t   

        # 3，logging-------------------------------------------------
        info = (epoch, err_s_label, err_s_domain, err_t_domain, err, accu_s, accu_t, best_accu_s, best_accu_t)
        dfhistory.loc[epoch - 1] = info
        torch.save(
            {
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': model.optimizer.state_dict(),
                'dfhistory': dfhistory
            }, model_save_path)
        if epoch > 1 and accu_t > dfhistory.loc[epoch - 2]["best_accu_t"]:
            torch.save(
                {
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': model.optimizer.state_dict(),
                    'dfhistory': dfhistory
                }, model_save_path + '_best') 
        
        nowtime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        print("\n"+"=========="*8 + "%s"%nowtime)

    print('Finished Training...')

    return dfhistory

# %%
dfhistory = train_model(model, epochs, train_loader, valid_loader, log_step_freq, model_save_path, epochs_to_save)
# Out:
# Start Training...
#  epoch: 1, [iter: 16 / all 16], err_s_label: 1.289452, err_s_domain: 0.690398, err_t_domain: 0.695634
# Accuracy of the source dataset: 0.874689
# Accuracy of the target dataset: 0.070281
#
#  epoch: 2, [iter: 16 / all 16], err_s_label: 1.219899, err_s_domain: 0.689674, err_t_domain: 0.695126
# Accuracy of the source dataset: 0.867945
# Accuracy of the target dataset: 0.054217
#
#  epoch: 3, [iter: 16 / all 16], err_s_label: 0.907833, err_s_domain: 0.689188, err_t_domain: 0.695539
# Accuracy of the source dataset: 0.857295
# Accuracy of the target dataset: 0.056225
#
#  epoch: 4, [iter: 16 / all 16], err_s_label: 1.194100, err_s_domain: 0.690276, err_t_domain: 0.693760
# Accuracy of the source dataset: 0.866525
# Accuracy of the target dataset: 0.060241
#
#  epoch: 5, [iter: 16 / all 16], err_s_label: 1.025381, err_s_domain: 0.691331, err_t_domain: 0.694138
# Accuracy of the source dataset: 0.849840
# Accuracy of the target dataset: 0.064257
#
#  epoch: 6, [iter: 16 / all 16], err_s_label: 1.270945, err_s_domain: 0.689318, err_t_domain: 0.693245
# Accuracy of the source dataset: 0.871140
# Accuracy of the target dataset: 0.058233
#
#  epoch: 7, [iter: 16 / all 16], err_s_label: 1.094993, err_s_domain: 0.688342, err_t_domain: 0.694542
# Accuracy of the source dataset: 0.869010
# Accuracy of the target dataset: 0.062249
#
#  epoch: 8, [iter: 16 / all 16], err_s_label: 1.083518, err_s_domain: 0.689394, err_t_domain: 0.692663
# Accuracy of the source dataset: 0.880369
# Accuracy of the target dataset: 0.068273
#
#  epoch: 9, [iter: 16 / all 16], err_s_label: 1.193870, err_s_domain: 0.690457, err_t_domain: 0.692135
# Accuracy of the source dataset: 0.877529
# Accuracy of the target dataset: 0.060241
#
#  epoch: 10, [iter: 16 / all 16], err_s_label: 1.295210, err_s_domain: 0.689733, err_t_domain: 0.693454
# Accuracy of the source dataset: 0.869365
# Accuracy of the target dataset: 0.044177
#
#  epoch: 11, [iter: 16 / all 16], err_s_label: 1.530974, err_s_domain: 0.690461, err_t_domain: 0.693379
# Accuracy of the source dataset: 0.864395
# Accuracy of the target dataset: 0.058233
#
#  epoch: 12, [iter: 16 / all 16], err_s_label: 1.471918, err_s_domain: 0.689067, err_t_domain: 0.689917
# Accuracy of the source dataset: 0.874689
# Accuracy of the target dataset: 0.060241
#
#  epoch: 13, [iter: 16 / all 16], err_s_label: 0.935712, err_s_domain: 0.687213, err_t_domain: 0.694306
# Accuracy of the source dataset: 0.862620
# Accuracy of the target dataset: 0.058233
#
#  epoch: 14, [iter: 16 / all 16], err_s_label: 1.085851, err_s_domain: 0.689214, err_t_domain: 0.692455
# Accuracy of the source dataset: 0.868655
# Accuracy of the target dataset: 0.068273
#
#  epoch: 15, [iter: 16 / all 16], err_s_label: 1.112317, err_s_domain: 0.689877, err_t_domain: 0.691995
# Accuracy of the source dataset: 0.869365
# Accuracy of the target dataset: 0.056225
#
#  epoch: 16, [iter: 16 / all 16], err_s_label: 1.068200, err_s_domain: 0.689203, err_t_domain: 0.691120
# Accuracy of the source dataset: 0.882854
# Accuracy of the target dataset: 0.052209
#
#  epoch: 17, [iter: 16 / all 16], err_s_label: 1.454565, err_s_domain: 0.690810, err_t_domain: 0.689509
# Accuracy of the source dataset: 0.870785
# Accuracy of the target dataset: 0.056225
#
#  epoch: 18, [iter: 16 / all 16], err_s_label: 1.000016, err_s_domain: 0.688877, err_t_domain: 0.695292
# Accuracy of the source dataset: 0.874334
# Accuracy of the target dataset: 0.064257
#
#  epoch: 19, [iter: 16 / all 16], err_s_label: 1.007760, err_s_domain: 0.689021, err_t_domain: 0.692547
# Accuracy of the source dataset: 0.871849
# Accuracy of the target dataset: 0.062249
#
#  epoch: 20, [iter: 16 / all 16], err_s_label: 1.088803, err_s_domain: 0.689420, err_t_domain: 0.691374
# Accuracy of the source dataset: 0.880369
# Accuracy of the target dataset: 0.064257
#
#  epoch: 21, [iter: 16 / all 16], err_s_label: 0.835651, err_s_domain: 0.686402, err_t_domain: 0.692038
# Accuracy of the source dataset: 0.879659
# Accuracy of the target dataset: 0.048193
#
#  epoch: 22, [iter: 16 / all 16], err_s_label: 1.108548, err_s_domain: 0.689148, err_t_domain: 0.688372
# Accuracy of the source dataset: 0.879659
# Accuracy of the target dataset: 0.058233
#
#  epoch: 23, [iter: 16 / all 16], err_s_label: 0.820965, err_s_domain: 0.687354, err_t_domain: 0.689735
# Accuracy of the source dataset: 0.883919
# Accuracy of the target dataset: 0.054217
#
#  epoch: 24, [iter: 16 / all 16], err_s_label: 1.127046, err_s_domain: 0.689927, err_t_domain: 0.691881
# Accuracy of the source dataset: 0.887114
# Accuracy of the target dataset: 0.060241
#
#  epoch: 25, [iter: 16 / all 16], err_s_label: 1.022573, err_s_domain: 0.688058, err_t_domain: 0.690921
# Accuracy of the source dataset: 0.878594
# Accuracy of the target dataset: 0.054217
#
#  epoch: 26, [iter: 16 / all 16], err_s_label: 1.155960, err_s_domain: 0.685904, err_t_domain: 0.688614
# Accuracy of the source dataset: 0.886404
# Accuracy of the target dataset: 0.064257
#
#  epoch: 27, [iter: 16 / all 16], err_s_label: 0.920274, err_s_domain: 0.686675, err_t_domain: 0.686131
# Accuracy of the source dataset: 0.886759
# Accuracy of the target dataset: 0.060241
#
#  epoch: 28, [iter: 16 / all 16], err_s_label: 1.194845, err_s_domain: 0.685610, err_t_domain: 0.687997
# Accuracy of the source dataset: 0.884629
# Accuracy of the target dataset: 0.060241
#
#  epoch: 29, [iter: 16 / all 16], err_s_label: 1.010657, err_s_domain: 0.685216, err_t_domain: 0.685896
# Accuracy of the source dataset: 0.899184
# Accuracy of the target dataset: 0.056225
#
#  epoch: 30, [iter: 16 / all 16], err_s_label: 1.141398, err_s_domain: 0.684136, err_t_domain: 0.685840
# Accuracy of the source dataset: 0.896699
# Accuracy of the target dataset: 0.062249
#
#  epoch: 31, [iter: 16 / all 16], err_s_label: 1.013819, err_s_domain: 0.686386, err_t_domain: 0.689850
# Accuracy of the source dataset: 0.890309
# Accuracy of the target dataset: 0.066265
#
#  epoch: 32, [iter: 16 / all 16], err_s_label: 0.977283, err_s_domain: 0.685832, err_t_domain: 0.685735
# Accuracy of the source dataset: 0.890664
# Accuracy of the target dataset: 0.064257
#
#  epoch: 33, [iter: 16 / all 16], err_s_label: 0.939793, err_s_domain: 0.684428, err_t_domain: 0.684808
# Accuracy of the source dataset: 0.877174
# Accuracy of the target dataset: 0.066265
#
#  epoch: 34, [iter: 16 / all 16], err_s_label: 0.987995, err_s_domain: 0.688003, err_t_domain: 0.684726
# Accuracy of the source dataset: 0.897054
# Accuracy of the target dataset: 0.072289
#
#  epoch: 35, [iter: 16 / all 16], err_s_label: 1.134030, err_s_domain: 0.686014, err_t_domain: 0.685328
# Accuracy of the source dataset: 0.886404
# Accuracy of the target dataset: 0.062249
#
#  epoch: 36, [iter: 16 / all 16], err_s_label: 1.025854, err_s_domain: 0.687837, err_t_domain: 0.684136
# Accuracy of the source dataset: 0.891374
# Accuracy of the target dataset: 0.058233
#
#  epoch: 37, [iter: 16 / all 16], err_s_label: 1.096266, err_s_domain: 0.686906, err_t_domain: 0.684574
# Accuracy of the source dataset: 0.893859
# Accuracy of the target dataset: 0.076305
#
#  epoch: 38, [iter: 16 / all 16], err_s_label: 0.879120, err_s_domain: 0.678976, err_t_domain: 0.690601
# Accuracy of the source dataset: 0.887469
# Accuracy of the target dataset: 0.084337
#
#  epoch: 39, [iter: 16 / all 16], err_s_label: 1.152925, err_s_domain: 0.679081, err_t_domain: 0.680689
# Accuracy of the source dataset: 0.898119
# Accuracy of the target dataset: 0.068273
#
#  epoch: 40, [iter: 16 / all 16], err_s_label: 0.881609, err_s_domain: 0.687110, err_t_domain: 0.682712
# Accuracy of the source dataset: 0.900603
# Accuracy of the target dataset: 0.052209
#
#  epoch: 41, [iter: 16 / all 16], err_s_label: 1.140224, err_s_domain: 0.691861, err_t_domain: 0.684536
# Accuracy of the source dataset: 0.898474
# Accuracy of the target dataset: 0.052209
#
#  epoch: 42, [iter: 16 / all 16], err_s_label: 0.826792, err_s_domain: 0.680849, err_t_domain: 0.680803
# Accuracy of the source dataset: 0.877174
# Accuracy of the target dataset: 0.056225
#
#  epoch: 43, [iter: 16 / all 16], err_s_label: 1.205223, err_s_domain: 0.685015, err_t_domain: 0.683373
# Accuracy of the source dataset: 0.906638
# Accuracy of the target dataset: 0.060241
#
#  epoch: 44, [iter: 16 / all 16], err_s_label: 1.213937, err_s_domain: 0.686249, err_t_domain: 0.674323
# Accuracy of the source dataset: 0.899184
# Accuracy of the target dataset: 0.052209
#
#  epoch: 45, [iter: 16 / all 16], err_s_label: 1.092702, err_s_domain: 0.690726, err_t_domain: 0.676401
# Accuracy of the source dataset: 0.904153
# Accuracy of the target dataset: 0.056225
#
#  epoch: 46, [iter: 16 / all 16], err_s_label: 1.271221, err_s_domain: 0.685264, err_t_domain: 0.679404
# Accuracy of the source dataset: 0.890664
# Accuracy of the target dataset: 0.072289
#
#  epoch: 47, [iter: 16 / all 16], err_s_label: 1.016197, err_s_domain: 0.686377, err_t_domain: 0.680832
# Accuracy of the source dataset: 0.903443
# Accuracy of the target dataset: 0.060241
#
#  epoch: 48, [iter: 16 / all 16], err_s_label: 1.023957, err_s_domain: 0.680374, err_t_domain: 0.687809
# Accuracy of the source dataset: 0.906638
# Accuracy of the target dataset: 0.056225
#
#  epoch: 49, [iter: 16 / all 16], err_s_label: 1.219463, err_s_domain: 0.683016, err_t_domain: 0.677548
# Accuracy of the source dataset: 0.892084
# Accuracy of the target dataset: 0.040161
#
#  epoch: 50, [iter: 16 / all 16], err_s_label: 1.015505, err_s_domain: 0.674789, err_t_domain: 0.684732
# Accuracy of the source dataset: 0.895279
# Accuracy of the target dataset: 0.064257
#
#  epoch: 51, [iter: 16 / all 16], err_s_label: 0.749534, err_s_domain: 0.674487, err_t_domain: 0.687494
# Accuracy of the source dataset: 0.900248
# Accuracy of the target dataset: 0.068273
#
#  epoch: 52, [iter: 16 / all 16], err_s_label: 0.710638, err_s_domain: 0.681782, err_t_domain: 0.677079
# Accuracy of the source dataset: 0.907703
# Accuracy of the target dataset: 0.058233
#
#  epoch: 53, [iter: 16 / all 16], err_s_label: 0.904528, err_s_domain: 0.682139, err_t_domain: 0.685375
# Accuracy of the source dataset: 0.901668
# Accuracy of the target dataset: 0.058233
#
#  epoch: 54, [iter: 16 / all 16], err_s_label: 0.796968, err_s_domain: 0.675402, err_t_domain: 0.677916
# Accuracy of the source dataset: 0.901668
# Accuracy of the target dataset: 0.064257
#
#  epoch: 55, [iter: 16 / all 16], err_s_label: 0.954679, err_s_domain: 0.683949, err_t_domain: 0.678720
# Accuracy of the source dataset: 0.907703
# Accuracy of the target dataset: 0.054217
#
#  epoch: 56, [iter: 16 / all 16], err_s_label: 0.992264, err_s_domain: 0.672028, err_t_domain: 0.677996
# Accuracy of the source dataset: 0.915158
# Accuracy of the target dataset: 0.060241
#
#  epoch: 57, [iter: 16 / all 16], err_s_label: 0.720386, err_s_domain: 0.682979, err_t_domain: 0.677024
# Accuracy of the source dataset: 0.910898
# Accuracy of the target dataset: 0.060241
#
#  epoch: 58, [iter: 16 / all 16], err_s_label: 0.847795, err_s_domain: 0.679577, err_t_domain: 0.680114
# Accuracy of the source dataset: 0.916933
# Accuracy of the target dataset: 0.058233
#
#  epoch: 59, [iter: 16 / all 16], err_s_label: 0.764582, err_s_domain: 0.672088, err_t_domain: 0.670981
# Accuracy of the source dataset: 0.917288
# Accuracy of the target dataset: 0.068273
#
#  epoch: 60, [iter: 16 / all 16], err_s_label: 0.738695, err_s_domain: 0.672690, err_t_domain: 0.682198
# Accuracy of the source dataset: 0.912673
# Accuracy of the target dataset: 0.062249
#
#  epoch: 61, [iter: 16 / all 16], err_s_label: 0.738807, err_s_domain: 0.664543, err_t_domain: 0.673876
# Accuracy of the source dataset: 0.910543
# Accuracy of the target dataset: 0.064257
#
#  epoch: 62, [iter: 16 / all 16], err_s_label: 0.918928, err_s_domain: 0.683737, err_t_domain: 0.675738
# Accuracy of the source dataset: 0.904863
# Accuracy of the target dataset: 0.058233
#
#  epoch: 63, [iter: 16 / all 16], err_s_label: 0.864224, err_s_domain: 0.677232, err_t_domain: 0.664289
# Accuracy of the source dataset: 0.910898
# Accuracy of the target dataset: 0.066265
#
#  epoch: 64, [iter: 16 / all 16], err_s_label: 0.740623, err_s_domain: 0.670697, err_t_domain: 0.690440
# Accuracy of the source dataset: 0.914093
# Accuracy of the target dataset: 0.084337
#
#  epoch: 65, [iter: 16 / all 16], err_s_label: 0.708501, err_s_domain: 0.676998, err_t_domain: 0.678228
# Accuracy of the source dataset: 0.918353
# Accuracy of the target dataset: 0.056225
#
#  epoch: 66, [iter: 16 / all 16], err_s_label: 0.942778, err_s_domain: 0.677090, err_t_domain: 0.663980
# Accuracy of the source dataset: 0.916578
# Accuracy of the target dataset: 0.060241
#
#  epoch: 67, [iter: 16 / all 16], err_s_label: 0.659444, err_s_domain: 0.682917, err_t_domain: 0.672642
# Accuracy of the source dataset: 0.921193
# Accuracy of the target dataset: 0.084337
#
#  epoch: 68, [iter: 16 / all 16], err_s_label: 0.955348, err_s_domain: 0.668944, err_t_domain: 0.685362
# Accuracy of the source dataset: 0.914803
# Accuracy of the target dataset: 0.078313
#
#  epoch: 69, [iter: 16 / all 16], err_s_label: 0.526250, err_s_domain: 0.676519, err_t_domain: 0.678631
# Accuracy of the source dataset: 0.918708
# Accuracy of the target dataset: 0.064257
#
#  epoch: 70, [iter: 16 / all 16], err_s_label: 0.540772, err_s_domain: 0.680871, err_t_domain: 0.664236
# Accuracy of the source dataset: 0.905218
# Accuracy of the target dataset: 0.066265
#
#  epoch: 71, [iter: 16 / all 16], err_s_label: 0.652840, err_s_domain: 0.663514, err_t_domain: 0.678277
# Accuracy of the source dataset: 0.910898
# Accuracy of the target dataset: 0.066265
#
#  epoch: 72, [iter: 16 / all 16], err_s_label: 0.848440, err_s_domain: 0.670155, err_t_domain: 0.662744
# Accuracy of the source dataset: 0.910898
# Accuracy of the target dataset: 0.064257
#
#  epoch: 73, [iter: 16 / all 16], err_s_label: 0.769235, err_s_domain: 0.672562, err_t_domain: 0.673518
# Accuracy of the source dataset: 0.922613
# Accuracy of the target dataset: 0.074297
#
#  epoch: 74, [iter: 16 / all 16], err_s_label: 0.580873, err_s_domain: 0.677184, err_t_domain: 0.677462
# Accuracy of the source dataset: 0.926163
# Accuracy of the target dataset: 0.066265
#
#  epoch: 75, [iter: 16 / all 16], err_s_label: 0.803076, err_s_domain: 0.679300, err_t_domain: 0.668356
# Accuracy of the source dataset: 0.927583
# Accuracy of the target dataset: 0.056225
#
#  epoch: 76, [iter: 16 / all 16], err_s_label: 0.821044, err_s_domain: 0.676837, err_t_domain: 0.681873
# Accuracy of the source dataset: 0.920483
# Accuracy of the target dataset: 0.068273
#
#  epoch: 77, [iter: 16 / all 16], err_s_label: 0.509169, err_s_domain: 0.659019, err_t_domain: 0.672333
# Accuracy of the source dataset: 0.912318
# Accuracy of the target dataset: 0.068273
#
#  epoch: 78, [iter: 16 / all 16], err_s_label: 0.833837, err_s_domain: 0.684195, err_t_domain: 0.676376
# Accuracy of the source dataset: 0.916933
# Accuracy of the target dataset: 0.066265
#
#  epoch: 79, [iter: 16 / all 16], err_s_label: 0.724474, err_s_domain: 0.665432, err_t_domain: 0.673415
# Accuracy of the source dataset: 0.919418
# Accuracy of the target dataset: 0.056225
#
#  epoch: 80, [iter: 16 / all 16], err_s_label: 0.672032, err_s_domain: 0.679759, err_t_domain: 0.670829
# Accuracy of the source dataset: 0.912318
# Accuracy of the target dataset: 0.062249
#
#  epoch: 81, [iter: 16 / all 16], err_s_label: 0.747784, err_s_domain: 0.670253, err_t_domain: 0.678347
# Accuracy of the source dataset: 0.930422
# Accuracy of the target dataset: 0.060241
#
#  epoch: 82, [iter: 16 / all 16], err_s_label: 0.769782, err_s_domain: 0.680327, err_t_domain: 0.675029
# Accuracy of the source dataset: 0.933262
# Accuracy of the target dataset: 0.066265
#
#  epoch: 83, [iter: 16 / all 16], err_s_label: 0.841264, err_s_domain: 0.667259, err_t_domain: 0.672571
# Accuracy of the source dataset: 0.922613
# Accuracy of the target dataset: 0.054217
#
#  epoch: 84, [iter: 16 / all 16], err_s_label: 0.709789, err_s_domain: 0.660923, err_t_domain: 0.670749
# Accuracy of the source dataset: 0.931487
# Accuracy of the target dataset: 0.068273
#
#  epoch: 85, [iter: 16 / all 16], err_s_label: 0.668693, err_s_domain: 0.674348, err_t_domain: 0.677304
# Accuracy of the source dataset: 0.931842
# Accuracy of the target dataset: 0.070281
#
#  epoch: 86, [iter: 16 / all 16], err_s_label: 0.903404, err_s_domain: 0.662814, err_t_domain: 0.676832
# Accuracy of the source dataset: 0.933972
# Accuracy of the target dataset: 0.078313
#
#  epoch: 87, [iter: 16 / all 16], err_s_label: 0.706309, err_s_domain: 0.674289, err_t_domain: 0.673032
# Accuracy of the source dataset: 0.929712
# Accuracy of the target dataset: 0.050201
#
#  epoch: 88, [iter: 16 / all 16], err_s_label: 0.591988, err_s_domain: 0.676907, err_t_domain: 0.663301
# Accuracy of the source dataset: 0.930422
# Accuracy of the target dataset: 0.060241
#
#  epoch: 89, [iter: 16 / all 16], err_s_label: 0.859124, err_s_domain: 0.671750, err_t_domain: 0.682085
# Accuracy of the source dataset: 0.923323
# Accuracy of the target dataset: 0.078313
#
#  epoch: 90, [iter: 16 / all 16], err_s_label: 0.984549, err_s_domain: 0.674428, err_t_domain: 0.670738
# Accuracy of the source dataset: 0.940007
# Accuracy of the target dataset: 0.074297
#
#  epoch: 91, [iter: 16 / all 16], err_s_label: 0.616475, err_s_domain: 0.675273, err_t_domain: 0.667354
# Accuracy of the source dataset: 0.934682
# Accuracy of the target dataset: 0.070281
#
#  epoch: 92, [iter: 16 / all 16], err_s_label: 0.772487, err_s_domain: 0.679081, err_t_domain: 0.681374
# Accuracy of the source dataset: 0.935037
# Accuracy of the target dataset: 0.078313
#
#  epoch: 93, [iter: 16 / all 16], err_s_label: 0.629483, err_s_domain: 0.677319, err_t_domain: 0.674077
# Accuracy of the source dataset: 0.913738
# Accuracy of the target dataset: 0.060241
#
#  epoch: 94, [iter: 16 / all 16], err_s_label: 0.839439, err_s_domain: 0.684171, err_t_domain: 0.683272
# Accuracy of the source dataset: 0.931132
# Accuracy of the target dataset: 0.036145
#
#  epoch: 95, [iter: 16 / all 16], err_s_label: 0.866792, err_s_domain: 0.686656, err_t_domain: 0.671930
# Accuracy of the source dataset: 0.933617
# Accuracy of the target dataset: 0.058233
#
#  epoch: 96, [iter: 16 / all 16], err_s_label: 0.643097, err_s_domain: 0.671624, err_t_domain: 0.694761
# Accuracy of the source dataset: 0.927938
# Accuracy of the target dataset: 0.056225
#
#  epoch: 97, [iter: 16 / all 16], err_s_label: 0.896665, err_s_domain: 0.671479, err_t_domain: 0.660325
# Accuracy of the source dataset: 0.933617
# Accuracy of the target dataset: 0.062249
#
#  epoch: 98, [iter: 16 / all 16], err_s_label: 0.581484, err_s_domain: 0.676715, err_t_domain: 0.678292
# Accuracy of the source dataset: 0.929357
# Accuracy of the target dataset: 0.056225
#
#  epoch: 99, [iter: 13 / all 16], err_s_label: 0.605142, err_s_domain: 0.670182, err_t_domain: 0.684992Accuracy of the target dataset: 0.068273
#
#  epoch: 106, [iter: 16 / all 16], err_s_label: 0.625524, err_s_domain: 0.674352, err_t_domain: 0.687384
# Accuracy of the source dataset: 0.943912
# Accuracy of the target dataset: 0.074297
#
#  epoch: 107, [iter: 16 / all 16], err_s_label: 0.649049, err_s_domain: 0.656198, err_t_domain: 0.686606
# Accuracy of the source dataset: 0.938942
# Accuracy of the target dataset: 0.066265
#
#  epoch: 108, [iter: 16 / all 16], err_s_label: 0.507470, err_s_domain: 0.657191, err_t_domain: 0.691241
# Accuracy of the source dataset: 0.939652
# Accuracy of the target dataset: 0.072289
#
#  epoch: 109, [iter: 16 / all 16], err_s_label: 0.721963, err_s_domain: 0.681906, err_t_domain: 0.679069
# Accuracy of the source dataset: 0.945332
# Accuracy of the target dataset: 0.070281
#
#  epoch: 110, [iter: 16 / all 16], err_s_label: 0.766709, err_s_domain: 0.698691, err_t_domain: 0.680775
# Accuracy of the source dataset: 0.946042
# Accuracy of the target dataset: 0.068273
#
#  epoch: 111, [iter: 16 / all 16], err_s_label: 0.809323, err_s_domain: 0.684364, err_t_domain: 0.683107
# Accuracy of the source dataset: 0.933262
# Accuracy of the target dataset: 0.078313
#
#  epoch: 112, [iter: 16 / all 16], err_s_label: 0.686091, err_s_domain: 0.681878, err_t_domain: 0.676150
# Accuracy of the source dataset: 0.945687
# Accuracy of the target dataset: 0.070281
#
#  epoch: 113, [iter: 16 / all 16], err_s_label: 0.612153, err_s_domain: 0.685777, err_t_domain: 0.663530
# Accuracy of the source dataset: 0.948527
# Accuracy of the target dataset: 0.062249
#
#  epoch: 114, [iter: 16 / all 16], err_s_label: 0.542716, err_s_domain: 0.682557, err_t_domain: 0.704450
# Accuracy of the source dataset: 0.942137
# Accuracy of the target dataset: 0.076305
#
#  epoch: 115, [iter: 16 / all 16], err_s_label: 0.524171, err_s_domain: 0.678533, err_t_domain: 0.680128
# Accuracy of the source dataset: 0.948882
# Accuracy of the target dataset: 0.076305
#
#  epoch: 116, [iter: 16 / all 16], err_s_label: 0.717322, err_s_domain: 0.678896, err_t_domain: 0.703203
# Accuracy of the source dataset: 0.946042
# Accuracy of the target dataset: 0.088353
#
#  epoch: 124, [iter: 16 / all 16], err_s_label: 0.566186, err_s_domain: 0.684842, err_t_domain: 0.678785
# Accuracy of the source dataset: 0.943912
# Accuracy of the target dataset: 0.076305
#
#  epoch: 125, [iter: 16 / all 16], err_s_label: 0.515605, err_s_domain: 0.685667, err_t_domain: 0.674083
# Accuracy of the source dataset: 0.937522
# Accuracy of the target dataset: 0.080321
#
#  epoch: 126, [iter: 16 / all 16], err_s_label: 0.665379, err_s_domain: 0.694340, err_t_domain: 0.698907
# Accuracy of the source dataset: 0.955627
# Accuracy of the target dataset: 0.086345
#
#  epoch: 127, [iter: 16 / all 16], err_s_label: 0.921196, err_s_domain: 0.682193, err_t_domain: 0.677896
# Accuracy of the source dataset: 0.942137
# Accuracy of the target dataset: 0.070281
#
#  epoch: 128, [iter: 16 / all 16], err_s_label: 0.753079, err_s_domain: 0.688955, err_t_domain: 0.681101
# Accuracy of the source dataset: 0.940007
# Accuracy of the target dataset: 0.078313
#
#  epoch: 129, [iter: 16 / all 16], err_s_label: 0.572992, err_s_domain: 0.681780, err_t_domain: 0.687264
# Accuracy of the source dataset: 0.946042
# Accuracy of the target dataset: 0.062249
#
#  epoch: 130, [iter: 16 / all 16], err_s_label: 0.637811, err_s_domain: 0.672642, err_t_domain: 0.683684
# Accuracy of the source dataset: 0.956337
# Accuracy of the target dataset: 0.080321
#
#  epoch: 131, [iter: 16 / all 16], err_s_label: 0.494048, err_s_domain: 0.682191, err_t_domain: 0.711958
# Accuracy of the source dataset: 0.955627
# Accuracy of the target dataset: 0.076305
#
#  epoch: 132, [iter: 16 / all 16], err_s_label: 0.602533, err_s_domain: 0.681642, err_t_domain: 0.671361
# Accuracy of the source dataset: 0.952787
# Accuracy of the target dataset: 0.076305
#
#  epoch: 133, [iter: 16 / all 16], err_s_label: 0.643168, err_s_domain: 0.686722, err_t_domain: 0.681880
# Accuracy of the source dataset: 0.958466
# Accuracy of the target dataset: 0.068273
#
#  epoch: 134, [iter: 16 / all 16], err_s_label: 0.735145, err_s_domain: 0.684320, err_t_domain: 0.674110
# Accuracy of the source dataset: 0.954562
# Accuracy of the target dataset: 0.074297
#
#  epoch: 135, [iter: 16 / all 16], err_s_label: 0.643876, err_s_domain: 0.697271, err_t_domain: 0.677567
# Accuracy of the source dataset: 0.932552
# Accuracy of the target dataset: 0.076305
#
#  epoch: 136, [iter: 16 / all 16], err_s_label: 0.536645, err_s_domain: 0.678595, err_t_domain: 0.699587
# Accuracy of the source dataset: 0.954207
# Accuracy of the target dataset: 0.074297
#
#  epoch: 137, [iter: 16 / all 16], err_s_label: 0.452973, err_s_domain: 0.665683, err_t_domain: 0.687386
# Accuracy of the source dataset: 0.955272
# Accuracy of the target dataset: 0.074297
#
#  epoch: 138, [iter: 16 / all 16], err_s_label: 0.595564, err_s_domain: 0.687646, err_t_domain: 0.693053
# Accuracy of the source dataset: 0.957756
# Accuracy of the target dataset: 0.086345
#
#  epoch: 139, [iter: 16 / all 16], err_s_label: 0.721968, err_s_domain: 0.689544, err_t_domain: 0.691580
# Accuracy of the source dataset: 0.958111
# Accuracy of the target dataset: 0.092369
#
#  epoch: 140, [iter: 16 / all 16], err_s_label: 0.449950, err_s_domain: 0.677435, err_t_domain: 0.693660
# Accuracy of the source dataset: 0.969471
# Accuracy of the target dataset: 0.088353
#
#  epoch: 141, [iter: 16 / all 16], err_s_label: 0.419420, err_s_domain: 0.676289, err_t_domain: 0.695985
# Accuracy of the source dataset: 0.959176
# Accuracy of the target dataset: 0.092369
#
#  epoch: 142, [iter: 16 / all 16], err_s_label: 0.548290, err_s_domain: 0.667293, err_t_domain: 0.686288
# Accuracy of the source dataset: 0.944622
# Accuracy of the target dataset: 0.070281
#
#  epoch: 143, [iter: 16 / all 16], err_s_label: 0.567482, err_s_domain: 0.680422, err_t_domain: 0.684307
# Accuracy of the source dataset: 0.951367
# Accuracy of the target dataset: 0.088353
#
#  epoch: 144, [iter: 16 / all 16], err_s_label: 0.777298, err_s_domain: 0.700406, err_t_domain: 0.683649
# Accuracy of the source dataset: 0.945332
# Accuracy of the target dataset: 0.094378
#
#  epoch: 153, [iter: 16 / all 16], err_s_label: 0.340870, err_s_domain: 0.669593, err_t_domain: 0.704883
# Accuracy of the source dataset: 0.968406
# Accuracy of the target dataset: 0.094378
#
#  epoch: 154, [iter: 16 / all 16], err_s_label: 0.898739, err_s_domain: 0.704160, err_t_domain: 0.688638
# Accuracy of the source dataset: 0.973731
# Accuracy of the target dataset: 0.088353
#
#  epoch: 155, [iter: 16 / all 16], err_s_label: 0.401384, err_s_domain: 0.690984, err_t_domain: 0.702215
# Accuracy of the source dataset: 0.972311
# Accuracy of the target dataset: 0.074297
#
#  epoch: 156, [iter: 16 / all 16], err_s_label: 0.615135, err_s_domain: 0.697334, err_t_domain: 0.680663
# Accuracy of the source dataset: 0.971601
# Accuracy of the target dataset: 0.088353
#
#  epoch: 157, [iter: 16 / all 16], err_s_label: 0.431096, err_s_domain: 0.676373, err_t_domain: 0.712881
# Accuracy of the source dataset: 0.977281
# Accuracy of the target dataset: 0.094378
#
#  epoch: 158, [iter: 16 / all 16], err_s_label: 0.371302, err_s_domain: 0.679560, err_t_domain: 0.690927
# Accuracy of the source dataset: 0.976571
# Accuracy of the target dataset: 0.088353
#
#  epoch: 159, [iter: 16 / all 16], err_s_label: 0.558434, err_s_domain: 0.686758, err_t_domain: 0.699786
# Accuracy of the source dataset: 0.979411
# Accuracy of the target dataset: 0.082329
#
#  epoch: 160, [iter: 16 / all 16], err_s_label: 0.583162, err_s_domain: 0.694343, err_t_domain: 0.702727
# Accuracy of the source dataset: 0.977636
# Accuracy of the target dataset: 0.082329
#
#  epoch: 161, [iter: 16 / all 16], err_s_label: 0.428506, err_s_domain: 0.680020, err_t_domain: 0.704508
# Accuracy of the source dataset: 0.975861
# Accuracy of the target dataset: 0.084337
#
#  epoch: 162, [iter: 16 / all 16], err_s_label: 0.495405, err_s_domain: 0.681582, err_t_domain: 0.691799
# Accuracy of the source dataset: 0.970891
# Accuracy of the target dataset: 0.080321
#
#  epoch: 163, [iter: 16 / all 16], err_s_label: 0.695940, err_s_domain: 0.684938, err_t_domain: 0.724622
# Accuracy of the source dataset: 0.972666
# Accuracy of the target dataset: 0.078313
#
#  epoch: 164, [iter: 16 / all 16], err_s_label: 0.509496, err_s_domain: 0.685307, err_t_domain: 0.700798
# Accuracy of the source dataset: 0.977281
# Accuracy of the target dataset: 0.072289
#
#  epoch: 165, [iter: 16 / all 16], err_s_label: 0.420143, err_s_domain: 0.689074, err_t_domain: 0.684385
# Accuracy of the source dataset: 0.976216
# Accuracy of the target dataset: 0.080321
#
#  epoch: 166, [iter: 16 / all 16], err_s_label: 0.369818, err_s_domain: 0.685747, err_t_domain: 0.702871
# Accuracy of the source dataset: 0.982251
# Accuracy of the target dataset: 0.074297
#
#  epoch: 167, [iter: 16 / all 16], err_s_label: 0.442544, err_s_domain: 0.672540, err_t_domain: 0.692375
# Accuracy of the source dataset: 0.982251
# Accuracy of the target dataset: 0.080321
#
#  epoch: 168, [iter: 16 / all 16], err_s_label: 0.332638, err_s_domain: 0.677755, err_t_domain: 0.711324
# Accuracy of the source dataset: 0.977991
# Accuracy of the target dataset: 0.082329
#
#  epoch: 169, [iter: 16 / all 16], err_s_label: 0.479922, err_s_domain: 0.688777, err_t_domain: 0.689054
# Accuracy of the source dataset: 0.983316
# Accuracy of the target dataset: 0.064257
#
#  epoch: 170, [iter: 16 / all 16], err_s_label: 0.414861, err_s_domain: 0.689543, err_t_domain: 0.713086
# Accuracy of the source dataset: 0.970891
# Accuracy of the target dataset: 0.094378
#
#  epoch: 171, [iter: 16 / all 16], err_s_label: 0.460423, err_s_domain: 0.688487, err_t_domain: 0.708177
# Accuracy of the source dataset: 0.967341
# Accuracy of the target dataset: 0.068273
#
#  epoch: 172, [iter: 16 / all 16], err_s_label: 0.592969, err_s_domain: 0.683410, err_t_domain: 0.690096
# Accuracy of the source dataset: 0.968406
# Accuracy of the target dataset: 0.082329
#
#  epoch: 173, [iter: 16 / all 16], err_s_label: 0.312231, err_s_domain: 0.686328, err_t_domain: 0.711722
# Accuracy of the source dataset: 0.977636
# Accuracy of the target dataset: 0.092369
#
#  epoch: 174, [iter: 16 / all 16], err_s_label: 0.259117, err_s_domain: 0.686288, err_t_domain: 0.706444
# Accuracy of the source dataset: 0.974086
# Accuracy of the target dataset: 0.068273
#
#  epoch: 175, [iter: 16 / all 16], err_s_label: 0.480199, err_s_domain: 0.689505, err_t_domain: 0.702968
# Accuracy of the source dataset: 0.980831
# Accuracy of the target dataset: 0.086345
#
#  epoch: 176, [iter: 16 / all 16], err_s_label: 0.360603, err_s_domain: 0.687793, err_t_domain: 0.691527
# Accuracy of the source dataset: 0.979056
# Accuracy of the target dataset: 0.086345
#
#  epoch: 177, [iter: 16 / all 16], err_s_label: 0.379216, err_s_domain: 0.683329, err_t_domain: 0.701647
# Accuracy of the source dataset: 0.981896
# Accuracy of the target dataset: 0.084337
#
#  epoch: 178, [iter: 16 / all 16], err_s_label: 0.334243, err_s_domain: 0.673661, err_t_domain: 0.698541
# Accuracy of the source dataset: 0.973021
# Accuracy of the target dataset: 0.072289
#
#  epoch: 179, [iter: 16 / all 16], err_s_label: 0.350791, err_s_domain: 0.689426, err_t_domain: 0.699972
# Accuracy of the source dataset: 0.978346
# Accuracy of the target dataset: 0.080321
#
#  epoch: 180, [iter: 16 / all 16], err_s_label: 0.424883, err_s_domain: 0.695742, err_t_domain: 0.703826
# Accuracy of the source dataset: 0.978346
# Accuracy of the target dataset: 0.094378
#
#  epoch: 181, [iter: 16 / all 16], err_s_label: 0.432441, err_s_domain: 0.689408, err_t_domain: 0.701478
# Accuracy of the source dataset: 0.974796
# Accuracy of the target dataset: 0.078313
#
#  epoch: 182, [iter: 16 / all 16], err_s_label: 0.443693, err_s_domain: 0.691726, err_t_domain: 0.694471
# Accuracy of the source dataset: 0.976216
# Accuracy of the target dataset: 0.074297
#
#  epoch: 183, [iter: 16 / all 16], err_s_label: 0.366865, err_s_domain: 0.684780, err_t_domain: 0.689335
# Accuracy of the source dataset: 0.974796
# Accuracy of the target dataset: 0.080321
#
#  epoch: 184, [iter: 16 / all 16], err_s_label: 0.285828, err_s_domain: 0.688780, err_t_domain: 0.698858
# Accuracy of the source dataset: 0.980476
# Accuracy of the target dataset: 0.076305
#
#  epoch: 185, [iter: 16 / all 16], err_s_label: 0.332303, err_s_domain: 0.679019, err_t_domain: 0.705267
# Accuracy of the source dataset: 0.982606
# Accuracy of the target dataset: 0.080321
#
#  epoch: 186, [iter: 16 / all 16], err_s_label: 0.460095, err_s_domain: 0.690408, err_t_domain: 0.707284
# Accuracy of the source dataset: 0.977636
# Accuracy of the target dataset: 0.088353
#
#  epoch: 187, [iter: 16 / all 16], err_s_label: 0.318375, err_s_domain: 0.685449, err_t_domain: 0.701918
# Accuracy of the source dataset: 0.984026
# Accuracy of the target dataset: 0.070281
#
#  epoch: 188, [iter: 16 / all 16], err_s_label: 0.352446, err_s_domain: 0.689164, err_t_domain: 0.692959
# Accuracy of the source dataset: 0.978701
# Accuracy of the target dataset: 0.080321
#
#  epoch: 189, [iter: 16 / all 16], err_s_label: 0.317754, err_s_domain: 0.690018, err_t_domain: 0.711858
# Accuracy of the source dataset: 0.980476
# Accuracy of the target dataset: 0.090361
#
#  epoch: 190, [iter: 16 / all 16], err_s_label: 0.524272, err_s_domain: 0.696207, err_t_domain: 0.698837
# Accuracy of the source dataset: 0.985091
# Accuracy of the target dataset: 0.086345
#
#  epoch: 191, [iter: 16 / all 16], err_s_label: 0.413840, err_s_domain: 0.687425, err_t_domain: 0.704807
# Accuracy of the source dataset: 0.982251
# Accuracy of the target dataset: 0.088353
#
#  epoch: 192, [iter: 16 / all 16], err_s_label: 0.449024, err_s_domain: 0.688856, err_t_domain: 0.690418
# Accuracy of the source dataset: 0.981541
# Accuracy of the target dataset: 0.070281
#
#  epoch: 193, [iter: 16 / all 16], err_s_label: 0.278316, err_s_domain: 0.682545, err_t_domain: 0.709929
# Accuracy of the source dataset: 0.983316
# Accuracy of the target dataset: 0.086345
#
#  epoch: 194, [iter: 16 / all 16], err_s_label: 0.369001, err_s_domain: 0.692190, err_t_domain: 0.696381
# Accuracy of the source dataset: 0.985800
# Accuracy of the target dataset: 0.090361
#
#  epoch: 195, [iter: 16 / all 16], err_s_label: 0.466226, err_s_domain: 0.693986, err_t_domain: 0.696644
# Accuracy of the source dataset: 0.978346
# Accuracy of the target dataset: 0.080321
#
#  epoch: 196, [iter: 16 / all 16], err_s_label: 0.513977, err_s_domain: 0.693812, err_t_domain: 0.723012
# Accuracy of the source dataset: 0.979411
# Accuracy of the target dataset: 0.096386
#
#  epoch: 197, [iter: 16 / all 16], err_s_label: 0.271483, err_s_domain: 0.687660, err_t_domain: 0.704722
# Accuracy of the source dataset: 0.982251
# Accuracy of the target dataset: 0.090361
#
#  epoch: 198, [iter: 16 / all 16], err_s_label: 0.445052, err_s_domain: 0.683470, err_t_domain: 0.697251
# Accuracy of the source dataset: 0.984381
# Accuracy of the target dataset: 0.088353
#
#  epoch: 199, [iter: 16 / all 16], err_s_label: 0.294974, err_s_domain: 0.694446, err_t_domain: 0.690973
# Accuracy of the source dataset: 0.964856
# Accuracy of the target dataset: 0.090361
#
#  epoch: 200, [iter: 16 / all 16], err_s_label: 0.281140, err_s_domain: 0.687545, err_t_domain: 0.703326
# Accuracy of the source dataset: 0.985091
# Accuracy of the target dataset: 0.068273
#
#  epoch: 201, [iter: 16 / all 16], err_s_label: 0.324905, err_s_domain: 0.693311, err_t_domain: 0.698424
# Accuracy of the source dataset: 0.989705
# Accuracy of the target dataset: 0.080321
#
#  epoch: 202, [iter: 16 / all 16], err_s_label: 0.379195, err_s_domain: 0.694204, err_t_domain: 0.694189
# Accuracy of the source dataset: 0.987575
# Accuracy of the target dataset: 0.082329
#
#  epoch: 203, [iter: 16 / all 16], err_s_label: 0.345950, err_s_domain: 0.687467, err_t_domain: 0.707380
# Accuracy of the source dataset: 0.982606
# Accuracy of the target dataset: 0.082329
#
#  epoch: 204, [iter: 16 / all 16], err_s_label: 0.305040, err_s_domain: 0.679938, err_t_domain: 0.695104
# Accuracy of the source dataset: 0.986510
# Accuracy of the target dataset: 0.076305
#
#  epoch: 205, [iter: 16 / all 16], err_s_label: 0.244836, err_s_domain: 0.689303, err_t_domain: 0.699980
# Accuracy of the source dataset: 0.983316
# Accuracy of the target dataset: 0.078313
#
#  epoch: 206, [iter: 16 / all 16], err_s_label: 0.290495, err_s_domain: 0.692434, err_t_domain: 0.703679
# Accuracy of the source dataset: 0.973021
# Accuracy of the target dataset: 0.080321
#
#  epoch: 207, [iter: 16 / all 16], err_s_label: 0.402480, err_s_domain: 0.693491, err_t_domain: 0.702235
# Accuracy of the source dataset: 0.983316
# Accuracy of the target dataset: 0.084337
#
#  epoch: 208, [iter: 16 / all 16], err_s_label: 0.278476, err_s_domain: 0.691349, err_t_domain: 0.696576
# Accuracy of the source dataset: 0.980476
# Accuracy of the target dataset: 0.084337
#
#  epoch: 209, [iter: 16 / all 16], err_s_label: 0.339123, err_s_domain: 0.688424, err_t_domain: 0.700307
# Accuracy of the source dataset: 0.984381
# Accuracy of the target dataset: 0.090361
#
#  epoch: 210, [iter: 16 / all 16], err_s_label: 0.408844, err_s_domain: 0.694784, err_t_domain: 0.692627
# Accuracy of the source dataset: 0.988285
# Accuracy of the target dataset: 0.084337
#
#  epoch: 211, [iter: 16 / all 16], err_s_label: 0.293472, err_s_domain: 0.686847, err_t_domain: 0.705476
# Accuracy of the source dataset: 0.981896
# Accuracy of the target dataset: 0.084337
#
#  epoch: 212, [iter: 16 / all 16], err_s_label: 0.427236, err_s_domain: 0.688717, err_t_domain: 0.699156
# Accuracy of the source dataset: 0.985800
# Accuracy of the target dataset: 0.082329
#
#  epoch: 213, [iter: 16 / all 16], err_s_label: 0.329228, err_s_domain: 0.685182, err_t_domain: 0.710595
# Accuracy of the source dataset: 0.981541
# Accuracy of the target dataset: 0.076305
#
#  epoch: 214, [iter: 16 / all 16], err_s_label: 0.329475, err_s_domain: 0.698381, err_t_domain: 0.701493
# Accuracy of the source dataset: 0.979766
# Accuracy of the target dataset: 0.080321
#
#  epoch: 215, [iter: 16 / all 16], err_s_label: 0.383750, err_s_domain: 0.692948, err_t_domain: 0.704289
# Accuracy of the source dataset: 0.989350
# Accuracy of the target dataset: 0.074297
#
#  epoch: 216, [iter: 16 / all 16], err_s_label: 0.258561, err_s_domain: 0.685907, err_t_domain: 0.701744
# Accuracy of the source dataset: 0.985800
# Accuracy of the target dataset: 0.082329
#
#  epoch: 217, [iter: 16 / all 16], err_s_label: 0.251083, err_s_domain: 0.681130, err_t_domain: 0.692500
# Accuracy of the source dataset: 0.985091
# Accuracy of the target dataset: 0.072289
#
#  epoch: 218, [iter: 16 / all 16], err_s_label: 0.204488, err_s_domain: 0.690041, err_t_domain: 0.701169
# Accuracy of the source dataset: 0.988995
# Accuracy of the target dataset: 0.084337
#
#  epoch: 219, [iter: 16 / all 16], err_s_label: 0.318914, err_s_domain: 0.695170, err_t_domain: 0.714074
# Accuracy of the source dataset: 0.987930
# Accuracy of the target dataset: 0.082329
#
#  epoch: 220, [iter: 16 / all 16], err_s_label: 0.273226, err_s_domain: 0.690036, err_t_domain: 0.702581
# Accuracy of the source dataset: 0.988285
# Accuracy of the target dataset: 0.088353
#
#  epoch: 221, [iter: 16 / all 16], err_s_label: 0.342387, err_s_domain: 0.692708, err_t_domain: 0.704850
# Accuracy of the source dataset: 0.988995
# Accuracy of the target dataset: 0.082329
#
#  epoch: 222, [iter: 16 / all 16], err_s_label: 0.258161, err_s_domain: 0.688733, err_t_domain: 0.716421
# Accuracy of the source dataset: 0.989350
# Accuracy of the target dataset: 0.078313
#
#  epoch: 223, [iter: 16 / all 16], err_s_label: 0.334436, err_s_domain: 0.683630, err_t_domain: 0.700987
# Accuracy of the source dataset: 0.986510
# Accuracy of the target dataset: 0.082329
#
#  epoch: 224, [iter: 16 / all 16], err_s_label: 0.237906, err_s_domain: 0.695908, err_t_domain: 0.704975
# Accuracy of the source dataset: 0.987220
# Accuracy of the target dataset: 0.078313
#
#  epoch: 225, [iter: 16 / all 16], err_s_label: 0.365277, err_s_domain: 0.689640, err_t_domain: 0.708539
# Accuracy of the source dataset: 0.985091
# Accuracy of the target dataset: 0.082329
#
#  epoch: 226, [iter: 16 / all 16], err_s_label: 0.271607, err_s_domain: 0.687492, err_t_domain: 0.698235
# Accuracy of the source dataset: 0.988285
# Accuracy of the target dataset: 0.084337
#
#  epoch: 227, [iter: 16 / all 16], err_s_label: 0.246481, err_s_domain: 0.685772, err_t_domain: 0.706093
# Accuracy of the source dataset: 0.988995
# Accuracy of the target dataset: 0.086345
#
#  epoch: 228, [iter: 16 / all 16], err_s_label: 0.466245, err_s_domain: 0.693480, err_t_domain: 0.709313
# Accuracy of the source dataset: 0.982961
# Accuracy of the target dataset: 0.084337
#
#  epoch: 229, [iter: 16 / all 16], err_s_label: 0.267312, err_s_domain: 0.687948, err_t_domain: 0.703793
# Accuracy of the source dataset: 0.967696
# Accuracy of the target dataset: 0.068273
#
#  epoch: 230, [iter: 16 / all 16], err_s_label: 0.274035, err_s_domain: 0.687709, err_t_domain: 0.701453
# Accuracy of the source dataset: 0.973021
# Accuracy of the target dataset: 0.062249
#
#  epoch: 231, [iter: 16 / all 16], err_s_label: 0.285584, err_s_domain: 0.679947, err_t_domain: 0.704745
# Accuracy of the source dataset: 0.982961
# Accuracy of the target dataset: 0.074297
#
#  epoch: 232, [iter: 16 / all 16], err_s_label: 0.380029, err_s_domain: 0.684821, err_t_domain: 0.695746
# Accuracy of the source dataset: 0.976926
# Accuracy of the target dataset: 0.072289
#
#  epoch: 233, [iter: 16 / all 16], err_s_label: 0.449475, err_s_domain: 0.684392, err_t_domain: 0.707567
# Accuracy of the source dataset: 0.984736
# Accuracy of the target dataset: 0.080321
#
#  epoch: 234, [iter: 16 / all 16], err_s_label: 0.344991, err_s_domain: 0.684773, err_t_domain: 0.696353
# Accuracy of the source dataset: 0.965921
# Accuracy of the target dataset: 0.086345
#
#  epoch: 235, [iter: 16 / all 16], err_s_label: 0.259037, err_s_domain: 0.689814, err_t_domain: 0.699890
# Accuracy of the source dataset: 0.956337
# Accuracy of the target dataset: 0.062249
#
#  epoch: 236, [iter: 16 / all 16], err_s_label: 0.407457, err_s_domain: 0.692371, err_t_domain: 0.697538
# Accuracy of the source dataset: 0.972666
# Accuracy of the target dataset: 0.076305
#
#  epoch: 237, [iter: 16 / all 16], err_s_label: 0.368551, err_s_domain: 0.686270, err_t_domain: 0.700420
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.086345
#
#  epoch: 238, [iter: 16 / all 16], err_s_label: 0.322575, err_s_domain: 0.691947, err_t_domain: 0.700132
# Accuracy of the source dataset: 0.973731
# Accuracy of the target dataset: 0.056225
#
#  epoch: 239, [iter: 16 / all 16], err_s_label: 0.290433, err_s_domain: 0.687780, err_t_domain: 0.704466
# Accuracy of the source dataset: 0.987220
# Accuracy of the target dataset: 0.080321
#
#  epoch: 240, [iter: 16 / all 16], err_s_label: 0.289012, err_s_domain: 0.677601, err_t_domain: 0.709038
# Accuracy of the source dataset: 0.987575
# Accuracy of the target dataset: 0.060241
#
#  epoch: 241, [iter: 16 / all 16], err_s_label: 0.244289, err_s_domain: 0.678356, err_t_domain: 0.705994
# Accuracy of the source dataset: 0.986155
# Accuracy of the target dataset: 0.084337
#
#  epoch: 242, [iter: 16 / all 16], err_s_label: 0.309045, err_s_domain: 0.686391, err_t_domain: 0.690122
# Accuracy of the source dataset: 0.988640
# Accuracy of the target dataset: 0.078313
#
#  epoch: 243, [iter: 16 / all 16], err_s_label: 0.284365, err_s_domain: 0.686189, err_t_domain: 0.697372
# Accuracy of the source dataset: 0.983671
# Accuracy of the target dataset: 0.082329
#
#  epoch: 244, [iter: 16 / all 16], err_s_label: 0.294237, err_s_domain: 0.684576, err_t_domain: 0.696802
# Accuracy of the source dataset: 0.986155
# Accuracy of the target dataset: 0.078313
#
#  epoch: 245, [iter: 16 / all 16], err_s_label: 0.206046, err_s_domain: 0.681190, err_t_domain: 0.704824
# Accuracy of the source dataset: 0.990060
# Accuracy of the target dataset: 0.072289
#
#  epoch: 246, [iter: 16 / all 16], err_s_label: 0.290666, err_s_domain: 0.684865, err_t_domain: 0.705259
# Accuracy of the source dataset: 0.985446
# Accuracy of the target dataset: 0.080321
#
#  epoch: 247, [iter: 16 / all 16], err_s_label: 0.171845, err_s_domain: 0.681581, err_t_domain: 0.700873
# Accuracy of the source dataset: 0.993965
# Accuracy of the target dataset: 0.074297
#
#  epoch: 248, [iter: 16 / all 16], err_s_label: 0.259002, err_s_domain: 0.686368, err_t_domain: 0.708508
# Accuracy of the source dataset: 0.993610
# Accuracy of the target dataset: 0.066265
#
#  epoch: 249, [iter: 16 / all 16], err_s_label: 0.225712, err_s_domain: 0.685599, err_t_domain: 0.698630
# Accuracy of the source dataset: 0.991480
# Accuracy of the target dataset: 0.070281
#
#  epoch: 250, [iter: 16 / all 16], err_s_label: 0.372463, err_s_domain: 0.683798, err_t_domain: 0.700050
# Accuracy of the source dataset: 0.993255
# Accuracy of the target dataset: 0.068273
#
#  epoch: 251, [iter: 14 / all 16], err_s_label: 0.222314, err_s_domain: 0.686682, err_t_domain: 0.706131Accuracy of the target dataset: 0.080321
#
#  epoch: 258, [iter: 16 / all 16], err_s_label: 0.327138, err_s_domain: 0.681177, err_t_domain: 0.697505
# Accuracy of the source dataset: 0.986865
# Accuracy of the target dataset: 0.082329
#
#  epoch: 259, [iter: 16 / all 16], err_s_label: 0.173521, err_s_domain: 0.684125, err_t_domain: 0.700073
# Accuracy of the source dataset: 0.992190
# Accuracy of the target dataset: 0.084337
#
#  epoch: 260, [iter: 16 / all 16], err_s_label: 0.155148, err_s_domain: 0.686679, err_t_domain: 0.696463
# Accuracy of the source dataset: 0.993255
# Accuracy of the target dataset: 0.078313
#
#  epoch: 261, [iter: 16 / all 16], err_s_label: 0.221126, err_s_domain: 0.688732, err_t_domain: 0.694627
# Accuracy of the source dataset: 0.991125
# Accuracy of the target dataset: 0.092369
#
#  epoch: 262, [iter: 16 / all 16], err_s_label: 0.399915, err_s_domain: 0.686103, err_t_domain: 0.706616
# Accuracy of the source dataset: 0.994320
# Accuracy of the target dataset: 0.072289
#
#  epoch: 263, [iter: 16 / all 16], err_s_label: 0.257176, err_s_domain: 0.685153, err_t_domain: 0.697790
# Accuracy of the source dataset: 0.992900
# Accuracy of the target dataset: 0.078313
#
#  epoch: 264, [iter: 16 / all 16], err_s_label: 0.274807, err_s_domain: 0.686436, err_t_domain: 0.705733
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.078313
#
#  epoch: 265, [iter: 16 / all 16], err_s_label: 0.197286, err_s_domain: 0.690704, err_t_domain: 0.701019
# Accuracy of the source dataset: 0.982961
# Accuracy of the target dataset: 0.076305
#
#  epoch: 266, [iter: 16 / all 16], err_s_label: 0.216436, err_s_domain: 0.687382, err_t_domain: 0.699165
# Accuracy of the source dataset: 0.992190
# Accuracy of the target dataset: 0.084337
#
#  epoch: 267, [iter: 16 / all 16], err_s_label: 0.234101, err_s_domain: 0.686182, err_t_domain: 0.694962
# Accuracy of the source dataset: 0.991480
# Accuracy of the target dataset: 0.082329
#
#  epoch: 268, [iter: 16 / all 16], err_s_label: 0.507864, err_s_domain: 0.685696, err_t_domain: 0.692923
# Accuracy of the source dataset: 0.992190
# Accuracy of the target dataset: 0.084337
#
#  epoch: 269, [iter: 16 / all 16], err_s_label: 0.303321, err_s_domain: 0.688686, err_t_domain: 0.706568
# Accuracy of the source dataset: 0.996095
# Accuracy of the target dataset: 0.080321
#
#  epoch: 270, [iter: 16 / all 16], err_s_label: 0.287467, err_s_domain: 0.684681, err_t_domain: 0.702055
# Accuracy of the source dataset: 0.990770
# Accuracy of the target dataset: 0.076305
#
#  epoch: 271, [iter: 16 / all 16], err_s_label: 0.244857, err_s_domain: 0.681555, err_t_domain: 0.693263
# Accuracy of the source dataset: 0.988995
# Accuracy of the target dataset: 0.084337
#
#  epoch: 272, [iter: 16 / all 16], err_s_label: 0.291071, err_s_domain: 0.692713, err_t_domain: 0.698001
# Accuracy of the source dataset: 0.981896
# Accuracy of the target dataset: 0.070281
#
#  epoch: 273, [iter: 16 / all 16], err_s_label: 0.232830, err_s_domain: 0.689672, err_t_domain: 0.703449
# Accuracy of the source dataset: 0.980121
# Accuracy of the target dataset: 0.080321
#
#  epoch: 274, [iter: 16 / all 16], err_s_label: 0.682853, err_s_domain: 0.687137, err_t_domain: 0.702671
# Accuracy of the source dataset: 0.959886
# Accuracy of the target dataset: 0.076305
#
#  epoch: 275, [iter: 16 / all 16], err_s_label: 0.264653, err_s_domain: 0.689398, err_t_domain: 0.695276
# Accuracy of the source dataset: 0.979766
# Accuracy of the target dataset: 0.066265
#
#  epoch: 276, [iter: 16 / all 16], err_s_label: 0.169879, err_s_domain: 0.687790, err_t_domain: 0.692867
# Accuracy of the source dataset: 0.985091
# Accuracy of the target dataset: 0.082329
#
#  epoch: 277, [iter: 16 / all 16], err_s_label: 0.442724, err_s_domain: 0.687053, err_t_domain: 0.705290
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.088353
#
#  epoch: 278, [iter: 16 / all 16], err_s_label: 0.253333, err_s_domain: 0.688034, err_t_domain: 0.702023
# Accuracy of the source dataset: 0.990770
# Accuracy of the target dataset: 0.066265
#
#  epoch: 279, [iter: 16 / all 16], err_s_label: 0.472576, err_s_domain: 0.680966, err_t_domain: 0.693833
# Accuracy of the source dataset: 0.989705
# Accuracy of the target dataset: 0.070281
#
#  epoch: 280, [iter: 16 / all 16], err_s_label: 0.222561, err_s_domain: 0.687049, err_t_domain: 0.699118
# Accuracy of the source dataset: 0.992900
# Accuracy of the target dataset: 0.082329
#
#  epoch: 281, [iter: 16 / all 16], err_s_label: 0.160294, err_s_domain: 0.686032, err_t_domain: 0.708795
# Accuracy of the source dataset: 0.992545
# Accuracy of the target dataset: 0.076305
#
#  epoch: 282, [iter: 16 / all 16], err_s_label: 0.273692, err_s_domain: 0.686180, err_t_domain: 0.697926
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.068273
#
#  epoch: 283, [iter: 16 / all 16], err_s_label: 0.421574, err_s_domain: 0.685475, err_t_domain: 0.704751
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.072289
#
#  epoch: 284, [iter: 16 / all 16], err_s_label: 0.426681, err_s_domain: 0.692635, err_t_domain: 0.691669
# Accuracy of the source dataset: 0.987575
# Accuracy of the target dataset: 0.066265
#
#  epoch: 285, [iter: 16 / all 16], err_s_label: 0.206755, err_s_domain: 0.684123, err_t_domain: 0.693903
# Accuracy of the source dataset: 0.984381
# Accuracy of the target dataset: 0.066265
#
#  epoch: 286, [iter: 16 / all 16], err_s_label: 0.268485, err_s_domain: 0.682062, err_t_domain: 0.698273
# Accuracy of the source dataset: 0.989705
# Accuracy of the target dataset: 0.064257
#
#  epoch: 287, [iter: 16 / all 16], err_s_label: 0.284213, err_s_domain: 0.686529, err_t_domain: 0.697879
# Accuracy of the source dataset: 0.993255
# Accuracy of the target dataset: 0.066265
#
#  epoch: 288, [iter: 16 / all 16], err_s_label: 0.340603, err_s_domain: 0.690322, err_t_domain: 0.691856
# Accuracy of the source dataset: 0.983671
# Accuracy of the target dataset: 0.078313
#
#  epoch: 289, [iter: 16 / all 16], err_s_label: 0.248190, err_s_domain: 0.686035, err_t_domain: 0.701114
# Accuracy of the source dataset: 0.983671
# Accuracy of the target dataset: 0.092369
#
#  epoch: 290, [iter: 16 / all 16], err_s_label: 0.300039, err_s_domain: 0.685410, err_t_domain: 0.696266
# Accuracy of the source dataset: 0.987220
# Accuracy of the target dataset: 0.080321
#
#  epoch: 291, [iter: 16 / all 16], err_s_label: 0.216950, err_s_domain: 0.688030, err_t_domain: 0.692491
# Accuracy of the source dataset: 0.967341
# Accuracy of the target dataset: 0.070281
#
#  epoch: 292, [iter: 16 / all 16], err_s_label: 0.346385, err_s_domain: 0.683903, err_t_domain: 0.694084
# Accuracy of the source dataset: 0.984736
# Accuracy of the target dataset: 0.064257
#
#  epoch: 293, [iter: 16 / all 16], err_s_label: 0.192391, err_s_domain: 0.685227, err_t_domain: 0.705040
# Accuracy of the source dataset: 0.980121
# Accuracy of the target dataset: 0.072289
#
#  epoch: 294, [iter: 16 / all 16], err_s_label: 0.191780, err_s_domain: 0.683245, err_t_domain: 0.702467
# Accuracy of the source dataset: 0.989350
# Accuracy of the target dataset: 0.070281
#
#  epoch: 295, [iter: 16 / all 16], err_s_label: 0.144910, err_s_domain: 0.682069, err_t_domain: 0.703853
# Accuracy of the source dataset: 0.986865
# Accuracy of the target dataset: 0.076305
#
#  epoch: 296, [iter: 16 / all 16], err_s_label: 0.214117, err_s_domain: 0.685081, err_t_domain: 0.698249
# Accuracy of the source dataset: 0.984736
# Accuracy of the target dataset: 0.068273
#
#  epoch: 297, [iter: 16 / all 16], err_s_label: 0.214794, err_s_domain: 0.688796, err_t_domain: 0.696323
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.064257
#
#  epoch: 298, [iter: 16 / all 16], err_s_label: 0.259433, err_s_domain: 0.686386, err_t_domain: 0.697694
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.074297
#
#  epoch: 299, [iter: 16 / all 16], err_s_label: 0.247500, err_s_domain: 0.684838, err_t_domain: 0.698214
# Accuracy of the source dataset: 0.991125
# Accuracy of the target dataset: 0.078313
#
#  epoch: 300, [iter: 16 / all 16], err_s_label: 0.122553, err_s_domain: 0.681870, err_t_domain: 0.693207
# Accuracy of the source dataset: 0.989705
# Accuracy of the target dataset: 0.066265
#
#  epoch: 301, [iter: 16 / all 16], err_s_label: 0.224026, err_s_domain: 0.690275, err_t_domain: 0.696593
# Accuracy of the source dataset: 0.990060
# Accuracy of the target dataset: 0.066265
#
#  epoch: 302, [iter: 16 / all 16], err_s_label: 0.173995, err_s_domain: 0.686176, err_t_domain: 0.702643
# Accuracy of the source dataset: 0.993965
# Accuracy of the target dataset: 0.072289
#
#  epoch: 303, [iter: 16 / all 16], err_s_label: 0.235659, err_s_domain: 0.683176, err_t_domain: 0.704162
# Accuracy of the source dataset: 0.991125
# Accuracy of the target dataset: 0.066265
#
#  epoch: 304, [iter: 16 / all 16], err_s_label: 0.285663, err_s_domain: 0.684761, err_t_domain: 0.701534
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.072289
#
#  epoch: 305, [iter: 16 / all 16], err_s_label: 0.225300, err_s_domain: 0.688926, err_t_domain: 0.700242
# Accuracy of the source dataset: 0.986155
# Accuracy of the target dataset: 0.060241
#
#  epoch: 306, [iter: 16 / all 16], err_s_label: 0.229562, err_s_domain: 0.684822, err_t_domain: 0.695721
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.068273
#
#  epoch: 307, [iter: 16 / all 16], err_s_label: 0.185871, err_s_domain: 0.686855, err_t_domain: 0.702223
# Accuracy of the source dataset: 0.993610
# Accuracy of the target dataset: 0.072289
#
#  epoch: 308, [iter: 16 / all 16], err_s_label: 0.265518, err_s_domain: 0.688753, err_t_domain: 0.708345
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.066265
#
#  epoch: 309, [iter: 16 / all 16], err_s_label: 0.227589, err_s_domain: 0.680919, err_t_domain: 0.699774
# Accuracy of the source dataset: 0.975151
# Accuracy of the target dataset: 0.074297
#
#  epoch: 310, [iter: 16 / all 16], err_s_label: 0.416961, err_s_domain: 0.686842, err_t_domain: 0.692611
# Accuracy of the source dataset: 0.993610
# Accuracy of the target dataset: 0.072289
#
#  epoch: 311, [iter: 16 / all 16], err_s_label: 0.360368, err_s_domain: 0.693531, err_t_domain: 0.705789
# Accuracy of the source dataset: 0.992190
# Accuracy of the target dataset: 0.074297
#
#  epoch: 312, [iter: 16 / all 16], err_s_label: 0.123269, err_s_domain: 0.684474, err_t_domain: 0.694252
# Accuracy of the source dataset: 0.991835
# Accuracy of the target dataset: 0.070281
#
#  epoch: 313, [iter: 16 / all 16], err_s_label: 0.170900, err_s_domain: 0.686824, err_t_domain: 0.697559
# Accuracy of the source dataset: 0.991480
# Accuracy of the target dataset: 0.064257
#
#  epoch: 314, [iter: 16 / all 16], err_s_label: 0.327500, err_s_domain: 0.683296, err_t_domain: 0.697801
# Accuracy of the source dataset: 0.990415
# Accuracy of the target dataset: 0.070281
#
#  epoch: 315, [iter: 16 / all 16], err_s_label: 0.207467, err_s_domain: 0.687677, err_t_domain: 0.699375
# Accuracy of the source dataset: 0.991480
# Accuracy of the target dataset: 0.056225
#
#  epoch: 316, [iter: 16 / all 16], err_s_label: 0.181747, err_s_domain: 0.685214, err_t_domain: 0.702825
# Accuracy of the source dataset: 0.991125
# Accuracy of the target dataset: 0.068273
#
#  epoch: 317, [iter: 16 / all 16], err_s_label: 0.241587, err_s_domain: 0.686752, err_t_domain: 0.699399
# Accuracy of the source dataset: 0.993255
# Accuracy of the target dataset: 0.074297
#
#  epoch: 318, [iter: 16 / all 16], err_s_label: 0.163083, err_s_domain: 0.684040, err_t_domain: 0.696524
# Accuracy of the source dataset: 0.994320
# Accuracy of the target dataset: 0.076305
#
#  epoch: 319, [iter: 16 / all 16], err_s_label: 0.232443, err_s_domain: 0.686777, err_t_domain: 0.697384
# Accuracy of the source dataset: 0.996095
# Accuracy of the target dataset: 0.074297
#
#  epoch: 320, [iter: 16 / all 16], err_s_label: 0.107057, err_s_domain: 0.684938, err_t_domain: 0.697931
# Accuracy of the source dataset: 0.995740
# Accuracy of the target dataset: 0.076305
#
#  epoch: 321, [iter: 16 / all 16], err_s_label: 0.216530, err_s_domain: 0.685311, err_t_domain: 0.693984
# Accuracy of the source dataset: 0.988995
# Accuracy of the target dataset: 0.070281
#
#  epoch: 322, [iter: 16 / all 16], err_s_label: 0.211326, err_s_domain: 0.689510, err_t_domain: 0.703044
# Accuracy of the source dataset: 0.987575
# Accuracy of the target dataset: 0.076305
#
#  epoch: 323, [iter: 16 / all 16], err_s_label: 0.309380, err_s_domain: 0.683990, err_t_domain: 0.701044
# Accuracy of the source dataset: 0.992900
# Accuracy of the target dataset: 0.078313
#
#  epoch: 324, [iter: 16 / all 16], err_s_label: 0.168372, err_s_domain: 0.683017, err_t_domain: 0.695835
# Accuracy of the source dataset: 0.988640
# Accuracy of the target dataset: 0.086345
#
#  epoch: 325, [iter: 16 / all 16], err_s_label: 0.138234, err_s_domain: 0.684847, err_t_domain: 0.693816
# Accuracy of the source dataset: 0.992545
# Accuracy of the target dataset: 0.082329
#
#  epoch: 326, [iter: 15 / all 16], err_s_label: 0.334542, err_s_domain: 0.684785, err_t_domain: 0.698200

# %% [markdown]
# ## Evaluate Model

# %%
# dfhistory

# %%
# %matplotlib inline
# def plot_metric(dfhistory, metric):
#     train_metrics = dfhistory[metric]
#     val_metrics = dfhistory['val_' + metric]
#     epochs = range(1, len(train_metrics) + 1)
#     plt.plot(epochs, train_metrics, 'bo--')
#     plt.plot(epochs, val_metrics, 'ro-')
#     plt.title('Training and validation '+ metric)
#     plt.xlabel("Epochs")
#     plt.ylabel(metric)
#     plt.legend(["train_"+metric, 'val_'+metric])
#     plt.show()

# %%
# plot_metric(dfhistory, "loss")

# %%
# plot_metric(dfhistory, "accuracy")

# %% [markdown]
# ## Use Model

# %%
# def predict(model, test_loader):
#     model.eval()
#     result = torch.cat([model.forward(t[0].to(device)) for t in test_loader])
#     return(result.data)

# %%
# y_pred_probs = predict(model, valid_loader)
# y_pred_probs

# %%
# y_pred = torch.where(y_pred_probs > 0.5,
#         torch.ones_like(y_pred_probs), torch.zeros_like(y_pred_probs))
# y_pred
